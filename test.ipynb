# %%
import sys

print(sys.executable)
# Out:
# c:\Users\dmitr\miniconda3\envs\master-ai\python.exe

# %%
import numpy
import pandas
import matplotlib
import sklearn

print("Все базовые библиотеки импортировались")
# Out:
# Все базовые библиотеки импортировались

# %%
import torch

print("Python:", sys.executable)
print("PyTorch:", torch.__version__)
print("CUDA used by PyTorch:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python: c:\Users\dmitr\miniconda3\envs\master-ai\python.exe
# PyTorch: 2.11.0+cu130
# CUDA used by PyTorch: 13.0
# CUDA available: True
# GPU: NVIDIA GeForce RTX 5070 Ti
